# %%
import os
import pandas as pd
from IPython.display import Image
tree = Image(filename=('Fig3a_phylotree.png'))
tree

# %%
python2 graphlan_annotate.py --annot annot_test_working2.txt Hydrolases5_tree_working.xml Hydrolases_evenbranches.xml
# Out:
#   File "<ipython-input-91-49434deabcab>", line 1
#     python2 graphlan_annotate.py --annot annot_test_working2.txt Hydrolases5_tree_working.xml Hydrolases_evenbranches.xml
#                             ^
# SyntaxError: invalid syntax
